# %%
import numpy as np

# %%
num = np.array([67,44,32,16,58,44,27])

# %% [markdown]
# ### mean

# %%
num.mean()
# Out:
# 41.142857142857146

# %%
np.mean(num)
# Out:
# 41.142857142857146

# %%
sum(num)/len(num)
# Out:
# 41.142857142857146

# %% [markdown]
# ### median

# %%
np.sort(num)
# Out:
# array([16, 27, 32, 44, 44, 58, 67])

# %%
np.median(num)
# Out:
# 44.0

# %% [markdown]
# ### mode

# %%
import pandas as pd

# %%
gender = pd.Series(['M','M','F','M','F','M','M','F'])

# %%
gender.value_counts()
# Out:
# M    5
# F    3
# dtype: int64

# %%
gender.mode()
# Out:
# 0    M
# dtype: object

# %%
ages = pd.Series([22,21,23,22,22,20,21,22,21,22,21,21])

# %%
ages.value_counts()
# Out:
# 22    5
# 21    5
# 23    1
# 20    1
# dtype: int64

# %%
ages.mode()
# Out:
# 0    21
# 1    22
# dtype: int64

# %%
x = np.arange(1,91)

# %%
x.mean()
# Out:
# 45.5

# %%
np.median(x)
# Out:
# 45.5

# %% [markdown]
# ### mid-range

# %%
(max(num)+min(num)) /2
# Out:
# 41.5

# %% [markdown]
# ### mean absolute deviationm

# %%
np.mean(abs(num-num.mean()))
# Out:
# 13.83673469387755

# %%
x = np.ones(10) + 20

# %%
x
# Out:
# array([21., 21., 21., 21., 21., 21., 21., 21., 21., 21.])

# %%
np.mean(abs(x-x.mean()))
# Out:
# 0.0

# %% [markdown]
# ### variance

# %%
np.mean((num-num.mean()) **2)
# Out:
# 269.265306122449

# %% [markdown]
# ### Standard deviation

# %%
np.sqrt(np.mean((num-num.mean()) **2))
# Out:
# 16.409305473494268

# %%
num.std()
# Out:
# 16.409305473494268

# %%
np.std(num)
# Out:
# 16.409305473494268

# %% [markdown]
# ### Structured Data Analysis

# %%
 # Survey Form: http://mitu.co.in/survey

# %%
# Dataset location: http://mitu.co.in/dataset
# Downlod file imcc.csv and save in current working directory

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\ADMIN'

# %% [markdown]
# ### import the dataset

# %%
df = pd.read_csv('imcc.csv')

# %%
df
# Out:
#               टाइमस्टँप  roll_num       name    middlename     surname   age  \
# 0   30/05/2023 14:26:35   2201184    Shubham        Kumar        Sinha  23.0
# 1   30/05/2023 14:26:56   2201129     Pranav      Prashant      Modale  25.0
# 2   30/05/2023 14:27:27   2201125    Pratik        Sharad     Masalkar   NaN
# 3   30/05/2023 14:27:43   2201154     Ranvir       Gajanan       Pawar   NaN
# 4   30/05/2023 14:27:48   2201193  Siddhesh         Suresh     Uttekar  21.0
# 5   30/05/2023 14:28:03   2201115     Sairaj       Shirish    Lumpatki  20.0
# 6   30/05/2023 14:28:03   2201110     Rahul          Kumar       Kumar  23.0
# 7   30/05/2023 14:28:06   2201124     Akash      Sambhaji      Markile   NaN
# 8   30/05/2023 14:28:07   2201145     harsh        subhash     patidar  22.0
# 9   30/05/2023 14:28:08   2201105      Omkar        Milind    Kulkarni  22.0
# 10  30/05/2023 14:28:10   2201171    Prajwal        Pramod     Shendge  21.0
# ...

# %%
df.shape
# Out:
# (51, 11)

# %%
list(df.columns)
# Out:
# ['टाइमस्टँप',
#  'roll_num',
#  'name',
#  'middlename',
#  'surname',
#  'age',
#  'sgpa',
#  'gender',
#  'favorite_sport',
#  'native_city',
#  'year_of_passing_10th']

# %%
df.head()
# Out:
#              टाइमस्टँप  roll_num       name middlename   surname   age  sgpa  \
# 0  30/05/2023 14:26:35   2201184    Shubham     Kumar      Sinha  23.0  8.29
# 1  30/05/2023 14:26:56   2201129     Pranav   Prashant    Modale  25.0  7.80
# 2  30/05/2023 14:27:27   2201125    Pratik     Sharad   Masalkar   NaN  8.31
# 3  30/05/2023 14:27:43   2201154     Ranvir    Gajanan     Pawar   NaN  8.00
# 4  30/05/2023 14:27:48   2201193  Siddhesh      Suresh   Uttekar  21.0  8.40
#
#   gender      favorite_sport native_city  year_of_passing_10th
# 0   Male  Cricket , Football       Patna                  2014
# 1   Male             Cricket        Pune                  2014
# 2   Male           Badminton        Pune                  2017
# 3   Male               chess     buldana                  2014
# 4   Male             cricket        Pune                  2016

# %%
df.head(3)
# Out:
#              टाइमस्टँप  roll_num     name middlename   surname   age  sgpa  \
# 0  30/05/2023 14:26:35   2201184  Shubham     Kumar      Sinha  23.0  8.29
# 1  30/05/2023 14:26:56   2201129   Pranav   Prashant    Modale  25.0  7.80
# 2  30/05/2023 14:27:27   2201125  Pratik     Sharad   Masalkar   NaN  8.31
#
#   gender      favorite_sport native_city  year_of_passing_10th
# 0   Male  Cricket , Football       Patna                  2014
# 1   Male             Cricket        Pune                  2014
# 2   Male           Badminton        Pune                  2017

# %%
df.tail()
# Out:
#               टाइमस्टँप  roll_num       name  middlename   surname   age  \
# 46  30/05/2023 14:30:39   2201157     Nikhil       Ashok     Rande   NaN
# 47  30/05/2023 14:31:04   2201118  ‎ Shubham    ‎ Sanjay    ‎ Mali  21.0
# 48  30/05/2023 14:31:14   2201194  shraddha   jaiprakash     varma  22.0
# 49  30/05/2023 14:31:18   2201106     Priya       Pradip  Kulkarni  22.0
# 50  30/05/2023 14:31:47   2201107    Swapnil       Suhas  Kulkarni  22.0
#
#     sgpa  gender favorite_sport native_city  year_of_passing_10th
# 46  7.00    Male        Kabaddi        Akot                  2016
# 47  9.15    Male      ‎ Cricket      ‎ Pune                  2017
# 48  7.89  Female      badminton        wani                  2017
# 49  8.00  Female      Badminton        Pune                  2017
# 50  7.28    Male        Cricket        Pune                  2016

# %%
df.dtypes
# Out:
# टाइमस्टँप                object
# roll_num                  int64
# name                     object
# middlename               object
# surname                  object
# age                     float64
# sgpa                    float64
# gender                   object
# favorite_sport           object
# native_city              object
# year_of_passing_10th      int64
# dtype: object

# %% [markdown]
# ### Slicing

# %%
df.iloc[2:9,3:8]
# Out:
#   middlename   surname   age  sgpa gender
# 2    Sharad   Masalkar   NaN  8.31   Male
# 3    Gajanan     Pawar   NaN  8.00   Male
# 4     Suresh   Uttekar  21.0  8.40   Male
# 5    Shirish  Lumpatki  20.0  8.71   Male
# 6      Kumar     Kumar  23.0  7.50   Male
# 7  Sambhaji    Markile   NaN  7.79   Male
# 8    subhash   patidar  22.0  8.00   Male

# %%
df.iloc[:9,3:8]
# Out:
#   middlename   surname   age  sgpa gender
# 0     Kumar      Sinha  23.0  8.29   Male
# 1   Prashant    Modale  25.0  7.80   Male
# 2    Sharad   Masalkar   NaN  8.31   Male
# 3    Gajanan     Pawar   NaN  8.00   Male
# 4     Suresh   Uttekar  21.0  8.40   Male
# 5    Shirish  Lumpatki  20.0  8.71   Male
# 6      Kumar     Kumar  23.0  7.50   Male
# 7  Sambhaji    Markile   NaN  7.79   Male
# 8    subhash   patidar  22.0  8.00   Male

# %%
df.iloc[:9,3:]
# Out:
#   middlename   surname   age  sgpa gender      favorite_sport native_city  \
# 0     Kumar      Sinha  23.0  8.29   Male  Cricket , Football       Patna
# 1   Prashant    Modale  25.0  7.80   Male             Cricket        Pune
# 2    Sharad   Masalkar   NaN  8.31   Male           Badminton        Pune
# 3    Gajanan     Pawar   NaN  8.00   Male               chess     buldana
# 4     Suresh   Uttekar  21.0  8.40   Male             cricket        Pune
# 5    Shirish  Lumpatki  20.0  8.71   Male          volleyball  Ahmednagar
# 6      Kumar     Kumar  23.0  7.50   Male           Badminton      Ranchi
# 7  Sambhaji    Markile   NaN  7.79   Male             Cricket       Latur
# 8    subhash   patidar  22.0  8.00   Male          volleyball      indore
#
#    year_of_passing_10th
# 0                  2014
# 1                  2014
# 2                  2017
# 3                  2014
# 4                  2016
# 5                  2017
# 6                  2015
# 7                  2016
# ...

# %%
x = df.iloc[:9,3:]
x
# Out:
#   middlename   surname   age  sgpa gender      favorite_sport native_city  \
# 0     Kumar      Sinha  23.0  8.29   Male  Cricket , Football       Patna
# 1   Prashant    Modale  25.0  7.80   Male             Cricket        Pune
# 2    Sharad   Masalkar   NaN  8.31   Male           Badminton        Pune
# 3    Gajanan     Pawar   NaN  8.00   Male               chess     buldana
# 4     Suresh   Uttekar  21.0  8.40   Male             cricket        Pune
# 5    Shirish  Lumpatki  20.0  8.71   Male          volleyball  Ahmednagar
# 6      Kumar     Kumar  23.0  7.50   Male           Badminton      Ranchi
# 7  Sambhaji    Markile   NaN  7.79   Male             Cricket       Latur
# 8    subhash   patidar  22.0  8.00   Male          volleyball      indore
#
#    year_of_passing_10th
# 0                  2014
# 1                  2014
# 2                  2017
# 3                  2014
# 4                  2016
# 5                  2017
# 6                  2015
# 7                  2016
# ...

# %%
df.iloc[2:9,2]
# Out:
# 2      Pratik
# 3       Ranvir
# 4    Siddhesh
# 5       Sairaj
# 6       Rahul
# 7       Akash
# 8       harsh
# Name: name, dtype: object

# %%
df.iloc[5,:]
# Out:
# टाइमस्टँप               30/05/2023 14:28:03
# roll_num                            2201115
# name                                 Sairaj
# middlename                          Shirish
# surname                            Lumpatki
# age                                      20
# sgpa                                   8.71
# gender                                 Male
# favorite_sport                   volleyball
# native_city                      Ahmednagar
# year_of_passing_10th                   2017
# Name: 5, dtype: object

# %%
df.iloc[[2,45,12,38,24],3:7]
# Out:
#       middlename   surname   age  sgpa
# 2        Sharad   Masalkar   NaN  8.31
# 45      Rajendra     kumar  22.0  9.60
# 12        Kailas      Raut   NaN  7.00
# 38       Sudhir    Manohar  22.0  7.54
# 24  Gorakshanth   kandekar  22.0  8.89

# %%
df.loc[:,'name']
# Out:
# 0       Shubham
# 1        Pranav
# 2       Pratik
# 3        Ranvir
# 4     Siddhesh
# 5        Sairaj
# 6        Rahul
# 7        Akash
# 8        harsh
# 9         Omkar
# 10      Prajwal
# 11       tejas
# 12      Vaibhav
# 13      Gaurav
# 14      sindura
# 15      Hitesh
# 16      Janhavi
# 17         Raj
# 18       Manish
# 19      muskan
# 20    Ashutosh
# 21        VIVEK
# 22    Sharvari
# 23       Leena
# 24      vedika
# 25     Atharva
# 26    himanshi
# 27     Harshita
# 28        Aditi
# 29      Akshata
# 30      Mahima
# 31    Aishwarya
# 32      Manali
# 33      Ankita
# 34         Yash
# 35     Apeksha
# 36     Saurabh
# 37      Kshitij
# 38     Sandesh
# 39        Suyog
# 40      Prerna
# 41       sakshi
# 42       Jyoti
# 43      NILESH
# 44       Pranav
# 45          Raj
# 46       Nikhil
# 47    ‎ Shubham
# 48    shraddha
# 49       Priya
# 50      Swapnil
# Name: name, dtype: object

# %%
df.loc[:,['name','gender','sgpa']]
# Out:
#          name  gender   sgpa
# 0     Shubham    Male   8.29
# 1      Pranav    Male   7.80
# 2     Pratik     Male   8.31
# 3      Ranvir    Male   8.00
# 4   Siddhesh     Male   8.40
# 5      Sairaj    Male   8.71
# 6      Rahul     Male   7.50
# 7      Akash     Male   7.79
# 8      harsh     Male   8.00
# 9       Omkar    Male   9.81
# 10    Prajwal    Male   7.90
# 11     tejas     Male   7.85
# 12    Vaibhav    Male   7.00
# 13    Gaurav     Male   8.90
# 14    sindura  Female   8.10
# 15    Hitesh     Male   8.25
# 16    Janhavi  Female   8.75
# 17       Raj     Male   7.71
# 18     Manish    Male   8.46
# 19    muskan   Female   8.05
# 20  Ashutosh     Male   7.54
# 21      VIVEK    Male   7.60
# 22  Sharvari   Female   7.82
# 23     Leena   Female   7.89
# 24    vedika   Female   8.89
# 25   Atharva     Male   7.64
# 26  himanshi   Female   8.80
# 27   Harshita  Female   8.61
# 28      Aditi  Female   8.00
# 29    Akshata  Female  75.00
# 30    Mahima   Female   7.68
# ...

# %%
df['name']
# Out:
# 0       Shubham
# 1        Pranav
# 2       Pratik
# 3        Ranvir
# 4     Siddhesh
# 5        Sairaj
# 6        Rahul
# 7        Akash
# 8        harsh
# 9         Omkar
# 10      Prajwal
# 11       tejas
# 12      Vaibhav
# 13      Gaurav
# 14      sindura
# 15      Hitesh
# 16      Janhavi
# 17         Raj
# 18       Manish
# 19      muskan
# 20    Ashutosh
# 21        VIVEK
# 22    Sharvari
# 23       Leena
# 24      vedika
# 25     Atharva
# 26    himanshi
# 27     Harshita
# 28        Aditi
# 29      Akshata
# 30      Mahima
# 31    Aishwarya
# 32      Manali
# 33      Ankita
# 34         Yash
# 35     Apeksha
# 36     Saurabh
# 37      Kshitij
# 38     Sandesh
# 39        Suyog
# 40      Prerna
# 41       sakshi
# 42       Jyoti
# 43      NILESH
# 44       Pranav
# 45          Raj
# 46       Nikhil
# 47    ‎ Shubham
# 48    shraddha
# 49       Priya
# 50      Swapnil
# Name: name, dtype: object

# %%
df[['name','middlename','surname']]
# Out:
#          name    middlename     surname
# 0     Shubham        Kumar        Sinha
# 1      Pranav      Prashant      Modale
# 2     Pratik        Sharad     Masalkar
# 3      Ranvir       Gajanan       Pawar
# 4   Siddhesh         Suresh     Uttekar
# 5      Sairaj       Shirish    Lumpatki
# 6      Rahul          Kumar       Kumar
# 7      Akash      Sambhaji      Markile
# 8      harsh        subhash     patidar
# 9       Omkar        Milind    Kulkarni
# 10    Prajwal        Pramod     Shendge
# 11     tejas    Uttareshwar        mane
# 12    Vaibhav        Kailas        Raut
# 13    Gaurav          Mohan      Shimpi
# 14    sindura         singh     rathore
# 15    Hitesh    Dnyaneshwar   Mohadikar
# 16    Janhavi          Ajit  Sangaonkar
# 17       Raj                      Verma
# 18     Manish       Maruti         Teke
# 19    muskan        shabbir      shipai
# 20  Ashutosh       Ghansham      Saoji
# 21      VIVEK      YESHAVNT        MORE
# ...

# %%
df.name
# Out:
# 0       Shubham
# 1        Pranav
# 2       Pratik
# 3        Ranvir
# 4     Siddhesh
# 5        Sairaj
# 6        Rahul
# 7        Akash
# 8        harsh
# 9         Omkar
# 10      Prajwal
# 11       tejas
# 12      Vaibhav
# 13      Gaurav
# 14      sindura
# 15      Hitesh
# 16      Janhavi
# 17         Raj
# 18       Manish
# 19      muskan
# 20    Ashutosh
# 21        VIVEK
# 22    Sharvari
# 23       Leena
# 24      vedika
# 25     Atharva
# 26    himanshi
# 27     Harshita
# 28        Aditi
# 29      Akshata
# 30      Mahima
# 31    Aishwarya
# 32      Manali
# 33      Ankita
# 34         Yash
# 35     Apeksha
# 36     Saurabh
# 37      Kshitij
# 38     Sandesh
# 39        Suyog
# 40      Prerna
# 41       sakshi
# 42       Jyoti
# 43      NILESH
# 44       Pranav
# 45          Raj
# 46       Nikhil
# 47    ‎ Shubham
# 48    shraddha
# 49       Priya
# 50      Swapnil
# Name: name, dtype: object

# %%
df.drop(4)
# Out:
#               टाइमस्टँप  roll_num       name    middlename     surname   age  \
# 0   30/05/2023 14:26:35   2201184    Shubham        Kumar        Sinha  23.0
# 1   30/05/2023 14:26:56   2201129     Pranav      Prashant      Modale  25.0
# 2   30/05/2023 14:27:27   2201125    Pratik        Sharad     Masalkar   NaN
# 3   30/05/2023 14:27:43   2201154     Ranvir       Gajanan       Pawar   NaN
# 5   30/05/2023 14:28:03   2201115     Sairaj       Shirish    Lumpatki  20.0
# 6   30/05/2023 14:28:03   2201110     Rahul          Kumar       Kumar  23.0
# 7   30/05/2023 14:28:06   2201124     Akash      Sambhaji      Markile   NaN
# 8   30/05/2023 14:28:07   2201145     harsh        subhash     patidar  22.0
# 9   30/05/2023 14:28:08   2201105      Omkar        Milind    Kulkarni  22.0
# 10  30/05/2023 14:28:10   2201171    Prajwal        Pramod     Shendge  21.0
# 11  30/05/2023 14:28:10   2201121     tejas    Uttareshwar        mane   NaN
# ...

# %%
df.drop([2,5,6,7])
# Out:
#               टाइमस्टँप  roll_num       name    middlename     surname   age  \
# 0   30/05/2023 14:26:35   2201184    Shubham        Kumar        Sinha  23.0
# 1   30/05/2023 14:26:56   2201129     Pranav      Prashant      Modale  25.0
# 3   30/05/2023 14:27:43   2201154     Ranvir       Gajanan       Pawar   NaN
# 4   30/05/2023 14:27:48   2201193  Siddhesh         Suresh     Uttekar  21.0
# 8   30/05/2023 14:28:07   2201145     harsh        subhash     patidar  22.0
# 9   30/05/2023 14:28:08   2201105      Omkar        Milind    Kulkarni  22.0
# 10  30/05/2023 14:28:10   2201171    Prajwal        Pramod     Shendge  21.0
# 11  30/05/2023 14:28:10   2201121     tejas    Uttareshwar        mane   NaN
# 12  30/05/2023 14:28:11   2201159    Vaibhav        Kailas        Raut   NaN
# 13  30/05/2023 14:28:13   2201173    Gaurav          Mohan      Shimpi  22.0
# 14  30/05/2023 14:28:15   2201182    sindura         singh     rathore  23.0
# ...

# %%
df.drop('टाइमस्टँप', axis=1,inplace=True)

# %%
df
# Out:
#     roll_num       name    middlename     surname   age   sgpa  gender  \
# 0    2201184    Shubham        Kumar        Sinha  23.0   8.29    Male
# 1    2201129     Pranav      Prashant      Modale  25.0   7.80    Male
# 2    2201125    Pratik        Sharad     Masalkar   NaN   8.31    Male
# 3    2201154     Ranvir       Gajanan       Pawar   NaN   8.00    Male
# 4    2201193  Siddhesh         Suresh     Uttekar  21.0   8.40    Male
# 5    2201115     Sairaj       Shirish    Lumpatki  20.0   8.71    Male
# 6    2201110     Rahul          Kumar       Kumar  23.0   7.50    Male
# 7    2201124     Akash      Sambhaji      Markile   NaN   7.79    Male
# 8    2201145     harsh        subhash     patidar  22.0   8.00    Male
# 9    2201105      Omkar        Milind    Kulkarni  22.0   9.81    Male
# 10   2201171    Prajwal        Pramod     Shendge  21.0   7.90    Male
# 11   2201121     tejas    Uttareshwar        mane   NaN   7.85    Male
# ...

# %% [markdown]
# ### Summary

# %%
df.describe()
# Out:
#            roll_num        age       sgpa  year_of_passing_10th
# count  5.100000e+01  39.000000  51.000000             51.000000
# mean   2.118559e+06  21.871795   9.383333           2016.352941
# std    3.889351e+05   0.893823   9.396436              1.110379
# min    2.201260e+05  20.000000   7.000000           2012.000000
# 25%    2.201118e+06  21.000000   7.620000           2016.000000
# 50%    2.201146e+06  22.000000   7.960000           2017.000000
# 75%    2.201174e+06  22.000000   8.430000           2017.000000
# max    2.201206e+06  25.000000  75.000000           2018.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   roll_num              51 non-null     int64
#  1   name                  51 non-null     object
#  2   middlename            51 non-null     object
#  3   surname               51 non-null     object
#  4   age                   39 non-null     float64
#  5   sgpa                  51 non-null     float64
#  6   gender                51 non-null     object
#  7   favorite_sport        51 non-null     object
#  8   native_city           51 non-null     object
#  9   year_of_passing_10th  51 non-null     int64
# dtypes: float64(2), int64(2), object(6)
# memory usage: 4.1+ KB

# %%
df.count()
# Out:
# roll_num                51
# name                    51
# middlename              51
# surname                 51
# age                     39
# sgpa                    51
# gender                  51
# favorite_sport          51
# native_city             51
# year_of_passing_10th    51
# dtype: int64

# %%
df.min()
# Out:
# roll_num                    220126
# name                      Saurabh
# middlename
# surname                     Madane
# age                             20
# sgpa                             7
# gender                      Female
# favorite_sport                   -
# native_city             Ahmednagar
# year_of_passing_10th          2012
# dtype: object

# %%
df.max()
# Out:
# roll_num                  2201206
# name                    ‎ Shubham
# middlename               ‎ Sanjay
# surname                    ‎ Mali
# age                            25
# sgpa                           75
# gender                       Male
# favorite_sport          ‎ Cricket
# native_city                ‎ Pune
# year_of_passing_10th         2018
# dtype: object

# %%
df.sum()
# Out:
# roll_num                                                        108046521
# name                    ShubhamPranavPratik RanvirSiddhesh SairajRahul...
# middlename              Kumar PrashantSharad GajananSureshShirishKumar...
# surname                 SinhaModaleMasalkarPawarUttekarLumpatkiKumarMa...
# age                                                                   853
# sgpa                                                               478.55
# gender                  MaleMaleMaleMaleMaleMaleMaleMaleMaleMaleMaleMa...
# favorite_sport          Cricket , FootballCricketBadmintonchesscricket...
# native_city             PatnaPunePunebuldanaPuneAhmednagarRanchiLaturi...
# year_of_passing_10th                                               102834
# dtype: object

# %%
df.mean()
# Out:
# roll_num                2.118559e+06
# age                     2.187179e+01
# sgpa                    9.383333e+00
# year_of_passing_10th    2.016353e+03
# dtype: float64

# %%
df.median()
# Out:
# roll_num                2201146.00
# age                          22.00
# sgpa                          7.96
# year_of_passing_10th       2017.00
# dtype: float64

# %%
df.std()
# Out:
# roll_num                388935.108564
# age                          0.893823
# sgpa                         9.396436
# year_of_passing_10th         1.110379
# dtype: float64

# %%
df['sgpa'].mean()
# Out:
# 9.383333333333333

# %%
df['sgpa'].max()
# Out:
# 75.0

# %%
df['sgpa'].sum()
# Out:
# 478.54999999999995

# %% [markdown]
# ### String Functions

# %%
df['name'].str.upper()
# Out:
# 0       SHUBHAM
# 1        PRANAV
# 2       PRATIK
# 3        RANVIR
# 4     SIDDHESH
# 5        SAIRAJ
# 6        RAHUL
# 7        AKASH
# 8        HARSH
# 9         OMKAR
# 10      PRAJWAL
# 11       TEJAS
# 12      VAIBHAV
# 13      GAURAV
# 14      SINDURA
# 15      HITESH
# 16      JANHAVI
# 17         RAJ
# 18       MANISH
# 19      MUSKAN
# 20    ASHUTOSH
# 21        VIVEK
# 22    SHARVARI
# 23       LEENA
# 24      VEDIKA
# 25     ATHARVA
# 26    HIMANSHI
# 27     HARSHITA
# 28        ADITI
# 29      AKSHATA
# 30      MAHIMA
# 31    AISHWARYA
# 32      MANALI
# 33      ANKITA
# 34         YASH
# 35     APEKSHA
# 36     SAURABH
# 37      KSHITIJ
# 38     SANDESH
# 39        SUYOG
# 40      PRERNA
# 41       SAKSHI
# 42       JYOTI
# 43      NILESH
# 44       PRANAV
# 45          RAJ
# 46       NIKHIL
# 47    ‎ SHUBHAM
# 48    SHRADDHA
# 49       PRIYA
# 50      SWAPNIL
# Name: name, dtype: object

# %%
df['name'].str.lower()
# Out:
# 0       shubham
# 1        pranav
# 2       pratik
# 3        ranvir
# 4     siddhesh
# 5        sairaj
# 6        rahul
# 7        akash
# 8        harsh
# 9         omkar
# 10      prajwal
# 11       tejas
# 12      vaibhav
# 13      gaurav
# 14      sindura
# 15      hitesh
# 16      janhavi
# 17         raj
# 18       manish
# 19      muskan
# 20    ashutosh
# 21        vivek
# 22    sharvari
# 23       leena
# 24      vedika
# 25     atharva
# 26    himanshi
# 27     harshita
# 28        aditi
# 29      akshata
# 30      mahima
# 31    aishwarya
# 32      manali
# 33      ankita
# 34         yash
# 35     apeksha
# 36     saurabh
# 37      kshitij
# 38     sandesh
# 39        suyog
# 40      prerna
# 41       sakshi
# 42       jyoti
# 43      nilesh
# 44       pranav
# 45          raj
# 46       nikhil
# 47    ‎ shubham
# 48    shraddha
# 49       priya
# 50      swapnil
# Name: name, dtype: object

# %%
df['name'].str.title()
# Out:
# 0       Shubham
# 1        Pranav
# 2       Pratik
# 3        Ranvir
# 4     Siddhesh
# 5        Sairaj
# 6        Rahul
# 7        Akash
# 8        Harsh
# 9         Omkar
# 10      Prajwal
# 11       Tejas
# 12      Vaibhav
# 13      Gaurav
# 14      Sindura
# 15      Hitesh
# 16      Janhavi
# 17         Raj
# 18       Manish
# 19      Muskan
# 20    Ashutosh
# 21        Vivek
# 22    Sharvari
# 23       Leena
# 24      Vedika
# 25     Atharva
# 26    Himanshi
# 27     Harshita
# 28        Aditi
# 29      Akshata
# 30      Mahima
# 31    Aishwarya
# 32      Manali
# 33      Ankita
# 34         Yash
# 35     Apeksha
# 36     Saurabh
# 37      Kshitij
# 38     Sandesh
# 39        Suyog
# 40      Prerna
# 41       Sakshi
# 42       Jyoti
# 43      Nilesh
# 44       Pranav
# 45          Raj
# 46       Nikhil
# 47    ‎ Shubham
# 48    Shraddha
# 49       Priya
# 50      Swapnil
# Name: name, dtype: object

# %%
df['name']
# Out:
# 0       Shubham
# 1        Pranav
# 2       Pratik
# 3        Ranvir
# 4     Siddhesh
# 5        Sairaj
# 6        Rahul
# 7        Akash
# 8        harsh
# 9         Omkar
# 10      Prajwal
# 11       tejas
# 12      Vaibhav
# 13      Gaurav
# 14      sindura
# 15      Hitesh
# 16      Janhavi
# 17         Raj
# 18       Manish
# 19      muskan
# 20    Ashutosh
# 21        VIVEK
# 22    Sharvari
# 23       Leena
# 24      vedika
# 25     Atharva
# 26    himanshi
# 27     Harshita
# 28        Aditi
# 29      Akshata
# 30      Mahima
# 31    Aishwarya
# 32      Manali
# 33      Ankita
# 34         Yash
# 35     Apeksha
# 36     Saurabh
# 37      Kshitij
# 38     Sandesh
# 39        Suyog
# 40      Prerna
# 41       sakshi
# 42       Jyoti
# 43      NILESH
# 44       Pranav
# 45          Raj
# 46       Nikhil
# 47    ‎ Shubham
# 48    shraddha
# 49       Priya
# 50      Swapnil
# Name: name, dtype: object

# %%
df['name'].str.strip()
# Out:
# 0       Shubham
# 1        Pranav
# 2        Pratik
# 3        Ranvir
# 4      Siddhesh
# 5        Sairaj
# 6         Rahul
# 7         Akash
# 8         harsh
# 9         Omkar
# 10      Prajwal
# 11        tejas
# 12      Vaibhav
# 13       Gaurav
# 14      sindura
# 15       Hitesh
# 16      Janhavi
# 17          Raj
# 18       Manish
# 19       muskan
# 20     Ashutosh
# 21        VIVEK
# 22     Sharvari
# 23        Leena
# 24       vedika
# 25      Atharva
# 26     himanshi
# 27     Harshita
# 28        Aditi
# 29      Akshata
# 30       Mahima
# 31    Aishwarya
# 32       Manali
# 33       Ankita
# 34         Yash
# 35      Apeksha
# 36      Saurabh
# 37      Kshitij
# 38      Sandesh
# 39        Suyog
# 40       Prerna
# 41       sakshi
# 42        Jyoti
# 43       NILESH
# 44       Pranav
# 45          Raj
# 46       Nikhil
# 47    ‎ Shubham
# 48     shraddha
# 49        Priya
# 50      Swapnil
# Name: name, dtype: object

# %%
df['name'] = df['name'].str.upper()
df['middlename'] = df['middlename'].str.upper()
df['surname'] = df['surname'].str.upper()
df['favorite_sport'] = df['favorite_sport'].str.upper()
df['native_city'] = df['native_city'].str.upper()

# %%
df
# Out:
#     roll_num       name    middlename     surname   age   sgpa  gender  \
# 0    2201184    SHUBHAM        KUMAR        SINHA  23.0   8.29    Male
# 1    2201129     PRANAV      PRASHANT      MODALE  25.0   7.80    Male
# 2    2201125    PRATIK        SHARAD     MASALKAR   NaN   8.31    Male
# 3    2201154     RANVIR       GAJANAN       PAWAR   NaN   8.00    Male
# 4    2201193  SIDDHESH         SURESH     UTTEKAR  21.0   8.40    Male
# 5    2201115     SAIRAJ       SHIRISH    LUMPATKI  20.0   8.71    Male
# 6    2201110     RAHUL          KUMAR       KUMAR  23.0   7.50    Male
# 7    2201124     AKASH      SAMBHAJI      MARKILE   NaN   7.79    Male
# 8    2201145     HARSH        SUBHASH     PATIDAR  22.0   8.00    Male
# 9    2201105      OMKAR        MILIND    KULKARNI  22.0   9.81    Male
# 10   2201171    PRAJWAL        PRAMOD     SHENDGE  21.0   7.90    Male
# 11   2201121     TEJAS    UTTARESHWAR        MANE   NaN   7.85    Male
# ...

# %%
df['name'] = df['name'].str.strip()
df['middlename'] = df['middlename'].str.strip()
df['surname'] = df['surname'].str.strip()
df['favorite_sport'] = df['favorite_sport'].str.strip()
df['native_city'] = df['native_city'].str.strip()

# %%
df
# Out:
#     roll_num       name    middlename     surname   age   sgpa  gender  \
# 0    2201184    SHUBHAM        KUMAR        SINHA  23.0   8.29    Male
# 1    2201129     PRANAV      PRASHANT      MODALE  25.0   7.80    Male
# 2    2201125     PRATIK       SHARAD     MASALKAR   NaN   8.31    Male
# 3    2201154     RANVIR       GAJANAN       PAWAR   NaN   8.00    Male
# 4    2201193   SIDDHESH        SURESH     UTTEKAR  21.0   8.40    Male
# 5    2201115     SAIRAJ       SHIRISH    LUMPATKI  20.0   8.71    Male
# 6    2201110      RAHUL         KUMAR       KUMAR  23.0   7.50    Male
# 7    2201124      AKASH     SAMBHAJI      MARKILE   NaN   7.79    Male
# 8    2201145      HARSH       SUBHASH     PATIDAR  22.0   8.00    Male
# 9    2201105      OMKAR        MILIND    KULKARNI  22.0   9.81    Male
# 10   2201171    PRAJWAL        PRAMOD     SHENDGE  21.0   7.90    Male
# 11   2201121      TEJAS   UTTARESHWAR        MANE   NaN   7.85    Male
# ...

# %%
df['name'] = df['name'].str.title()
df['middlename'] = df['middlename'].str.title()
df['surname'] = df['surname'].str.title()
df['favorite_sport'] = df['favorite_sport'].str.title()
df['native_city'] = df['native_city'].str.title()

# %%
df
# Out:
#     roll_num       name    middlename     surname   age   sgpa  gender  \
# 0    2201184    Shubham        KUMAR        SINHA  23.0   8.29    Male
# 1    2201129     Pranav      PRASHANT      MODALE  25.0   7.80    Male
# 2    2201125     Pratik       SHARAD     MASALKAR   NaN   8.31    Male
# 3    2201154     Ranvir       GAJANAN       PAWAR   NaN   8.00    Male
# 4    2201193   Siddhesh        SURESH     UTTEKAR  21.0   8.40    Male
# 5    2201115     Sairaj       SHIRISH    LUMPATKI  20.0   8.71    Male
# 6    2201110      Rahul         KUMAR       KUMAR  23.0   7.50    Male
# 7    2201124      Akash     SAMBHAJI      MARKILE   NaN   7.79    Male
# 8    2201145      Harsh       SUBHASH     PATIDAR  22.0   8.00    Male
# 9    2201105      Omkar        MILIND    KULKARNI  22.0   9.81    Male
# 10   2201171    Prajwal        PRAMOD     SHENDGE  21.0   7.90    Male
# 11   2201121      Tejas   UTTARESHWAR        MANE   NaN   7.85    Male
# ...

# %%
df.isnull()
# Out:
#     roll_num   name  middlename  surname    age   sgpa  gender  \
# 0      False  False       False    False  False  False   False
# 1      False  False       False    False  False  False   False
# 2      False  False       False    False   True  False   False
# 3      False  False       False    False   True  False   False
# 4      False  False       False    False  False  False   False
# 5      False  False       False    False  False  False   False
# 6      False  False       False    False  False  False   False
# 7      False  False       False    False   True  False   False
# 8      False  False       False    False  False  False   False
# 9      False  False       False    False  False  False   False
# 10     False  False       False    False  False  False   False
# 11     False  False       False    False   True  False   False
# 12     False  False       False    False   True  False   False
# 13     False  False       False    False  False  False   False
# ...

# %%
False + True
# Out:
# 1

# %%
True + True
# Out:
# 2

# %%
df.isnull().sum()
# Out:
# roll_num                 0
# name                     0
# middlename               0
# surname                  0
# age                     12
# sgpa                     0
# gender                   0
# favorite_sport           0
# native_city              0
# year_of_passing_10th     0
# dtype: int64

# %%
df['age'] = df['age'].fillna(df['age'].median())

# %%
df
# Out:
#     roll_num       name   middlename     surname   age   sgpa  gender  \
# 0    2201184    Shubham        Kumar       Sinha  23.0   8.29    Male
# 1    2201129     Pranav     Prashant      Modale  25.0   7.80    Male
# 2    2201125     Pratik       Sharad    Masalkar  22.0   8.31    Male
# 3    2201154     Ranvir      Gajanan       Pawar  22.0   8.00    Male
# 4    2201193   Siddhesh       Suresh     Uttekar  21.0   8.40    Male
# 5    2201115     Sairaj      Shirish    Lumpatki  20.0   8.71    Male
# 6    2201110      Rahul        Kumar       Kumar  23.0   7.50    Male
# 7    2201124      Akash     Sambhaji     Markile  22.0   7.79    Male
# 8    2201145      Harsh      Subhash     Patidar  22.0   8.00    Male
# 9    2201105      Omkar       Milind    Kulkarni  22.0   9.81    Male
# 10   2201171    Prajwal       Pramod     Shendge  21.0   7.90    Male
# 11   2201121      Tejas  Uttareshwar        Mane  22.0   7.85    Male
# ...

# %% [markdown]
# ### boolean filtering

# %%
df[df['sgpa'] > 10]
# Out:
#     roll_num     name middlename surname   age  sgpa  gender favorite_sport  \
# 29   2201188  Akshata      Vijay  Thakre  22.0  75.0  Female        Cricket
#
#    native_city  year_of_passing_10th
# 29        Pune                  2017

# %%
df.loc[29,'sgpa'] = 7.5

# %%
df['sgpa'].min(),df['sgpa'].max()
# Out:
# (7.0, 10.0)

# %%
df[df['sgpa'] > 9]
# Out:
#     roll_num       name middlename   surname   age   sgpa  gender  \
# 9    2201105      Omkar     Milind  Kulkarni  22.0   9.81    Male
# 31   2201113  Aishwarya     Prasad  Lokhande  22.0   9.10  Female
# 41    220143     Sakshi    Santosh   Patidar  22.0  10.00  Female
# 45   2201167        Raj   Rajendra     Kumar  22.0   9.60    Male
# 47   2201118  ‎ Shubham   ‎ Sanjay    ‎ Mali  21.0   9.15    Male
#
#       favorite_sport native_city  year_of_passing_10th
# 9   Sachin Tendulkar        Pune                  2018
# 31         Badminton        Pune                  2017
# 41           Cricket        Durg                  2015
# 45           Cricket        Pune                  2016
# 47         ‎ Cricket      ‎ Pune                  2017

# %%
df['favorite_sport'].mode()
# Out:
# 0    Cricket
# dtype: object

# %%
df['favorite_sport'].value_counts()
# Out:
# Cricket               24
# Badminton             10
# Football               4
# Table Tennis           2
# Volleyball             2
# Vollyball              1
# Cricket , Football     1
# Chess                  1
# Basketball             1
# Carrom                 1
# Kabaddi                1
# ‎ Cricket              1
# -                      1
# Sachin Tendulkar       1
# Name: favorite_sport, dtype: int64

# %%
df[(df['gender']=='Female')&(df['favorite_sport']=='Cricket')]
# Out:
#     roll_num      name middlename  surname   age   sgpa  gender  \
# 14   2201182   Sindura      Singh  Rathore  23.0   8.10  Female
# 19   1951022    Muskan    Shabbir   Shipai  21.0   8.05  Female
# 22   2201175  Sharvari      Sunil   Shinde  22.0   7.82  Female
# 26   2201196  Himanshi                Vyas  22.0   8.80  Female
# 29   2201188   Akshata      Vijay   Thakre  22.0   7.50  Female
# 33   2201116    Ankita     Tanaji   Madane  22.0   7.00  Female
# 41    220143    Sakshi    Santosh  Patidar  22.0  10.00  Female
# 42   2201205     Jyoti          .    Yadav  22.0   8.14  Female
#
#    favorite_sport  native_city  year_of_passing_10th
# 14        Cricket  Muzzafarpur                  2017
# 19        Cricket         Pune                  2017
# 22        Cricket        Karad                  2016
# 26        Cricket       Indore                  2017
# 29        Cricket         Pune                  2017
# 33        Cricket        Karad                  2017
# ...

# %%
df[df['year_of_passing_10th']== 2015]['name'].count()
# Out:
# 4

# %%
x=df[(df['gender']=='Female')&(df['favorite_sport']=='Cricket')]

# %%
x.to_csv('output.csv',index=False)
